# %%
import os

# %%
BASE_DIR = r"C:\Users\SHAIKH\OneDrive\Desktop\ML\ML\dataset"
BENIGN_DIR = os.path.join(BASE_DIR, "benign")
MALWARE_DIR = os.path.join(BASE_DIR, "malware")

# %%
benign_files = [f for f in os.listdir(BENIGN_DIR) if f.endswith(".apk")]
malware_files = [f for f in os.listdir(MALWARE_DIR) if f.endswith(".apk")]

print("\nCurrent APKs in benign folder:", len(benign_files))
print(benign_files)
print("\nCurrent APKs in malware folder:", len(malware_files))
print(malware_files)
# Out:
# Current APKs in benign folder: 4
# ['ChatGPT[1].apk', 'Google_Play_Store[1].apk', 'WhatsApp[1].apk', 'YouTube[1].apk']
#
# Current APKs in malware folder: 4
# ['LuckyPatchers.com_Official_Installer_11.9.6[1].apk', 'moan_2.0_APKPure[1].apk', 'org.ppsspp.ppssppgold--117010000[1].apk', 'PikaShow_APK_v83_[Original_File]_-_(PikaShowHD.com)[1].apk']

# %%
print("\n✅ Place your benign APKs in:", BENIGN_DIR)
print("✅ Place your malware APKs in:", MALWARE_DIR)
print("\nAfter adding APKs, proceed to 02_extract_features.ipynb")
# Out:
# ✅ Place your benign APKs in: C:\Users\SHAIKH\OneDrive\Desktop\ML\ML\dataset\benign
# ✅ Place your malware APKs in: C:\Users\SHAIKH\OneDrive\Desktop\ML\ML\dataset\malware
#
# After adding APKs, proceed to 02_extract_features.ipynb
