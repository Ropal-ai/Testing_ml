# %%
import pandas as pd
import os
import pickle
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
BASE_DATASET = r"C:/Users/Sonali/Desktop/ml/dataset"
FEATURES_PATH = os.path.join(BASE_DATASET, "extracted_permission.csv")
MODEL_DIR = "../models"
os.makedirs(MODEL_DIR, exist_ok=True)

# %%
df = pd.read_csv(FEATURES_PATH)

print("Columns found:", df.columns)
# Out:
# Columns found: Index(['ACCESS_FINE_LOCATION', 'ACCESS_NETWORK_STATE',
#        'ACCESS_NOTIFICATION_POLICY', 'ACCESS_WIFI_STATE', 'AD_ID',
#        'BADGE_COUNT_READ', 'BADGE_COUNT_WRITE',
#        'BIND_GET_INSTALL_REFERRER_SERVICE', 'BLUETOOTH', 'BROADCAST_BADGE',
#        'C2D_MESSAGE', 'CHANGE_BADGE', 'CHANGE_WIFI_STATE',
#        'FOREGROUND_SERVICE', 'FULL', 'INTERNET', 'PROVIDER_INSERT_BADGE',
#        'QUERY_ALL_PACKAGES', 'READ', 'READ_APP_BADGE', 'READ_EXTERNAL_STORAGE',
#        'READ_SETTINGS', 'RECEIVE', 'RECEIVE_BOOT_COMPLETED',
#        'REQUEST_DELETE_PACKAGES', 'REQUEST_INSTALL_PACKAGES',
#        'SYSTEM_ALERT_WINDOW', 'UPDATE_BADGE', 'UPDATE_COUNT',
#        'UPDATE_SHORTCUT', 'VIBRATE', 'WAKE_LOCK', 'WRITE',
#        'WRITE_EXTERNAL_STORAGE', 'WRITE_SETTINGS', 'label'],
#       dtype='object')

# %%
# X = all permission columns
X = df.drop("label", axis=1)

# y = label column
y = df["label"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.5, random_state=42, stratify=y
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(
#       2     X, y, test_size=0.5, random_state=42, stratify=y
#       3 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_split.py:2940, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2936         CVClass = ShuffleSplit
#    2938     cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
# -> 2940     train, test = next(cv.split(X=arrays[0], y=stratify))
#    2942 train, test = ensure_common_namespace_device(arrays[0], train, test)
#    2944 return list(
#    2945     chain.from_iterable(
#    2946         (_safe_indexing(a, train), _safe_indexing(a, test)) for a in arrays
#    2947     )
#    2948 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_split.py:1927, in BaseShuffleSplit.split(self, X, y, groups)
#    1897 """Generate indices to split data into training and test set.
#    1898
#    1899 Parameters
#    (...)   1924 to an integer.
#    1925 """
#    1926 X, y, groups = indexable(X, y, groups)
# -> 1927 for train, test in self._iter_indices(X, y, groups):
#    1928     yield train, test
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_split.py:2342, in StratifiedShuffleSplit._iter_indices(self, X, y, groups)
#    2340 class_counts = np.bincount(y_indices)
#    2341 if np.min(class_counts) < 2:
# -> 2342     raise ValueError(
#    2343         "The least populated class in y has only 1"
#    2344         " member, which is too few. The minimum"
#    2345         " number of groups for any class cannot"
#    2346         " be less than 2."
#    2347     )
#    2349 if n_train < n_classes:
#    2350     raise ValueError(
#    2351         "The train_size = %d should be greater or "
#    2352         "equal to the number of classes = %d" % (n_train, n_classes)
#    2353     )
#
# ValueError: The least populated class in y has only 1 member, which is too few. The minimum number of groups for any class cannot be less than 2.

# %%
with open(os.path.join(MODEL_DIR, "apk_classifier.pkl"), "wb") as f:
    pickle.dump(clf, f)

print("Model saved at:", os.path.join(MODEL_DIR, "apk_classifier.pkl"))

# %%
y_pred = clf.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.5
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.50      1.00      0.67         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
#
# Confusion Matrix:
#  [[0 1]
#  [0 1]]
# C:\Users\Sonali\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sonali\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sonali\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
